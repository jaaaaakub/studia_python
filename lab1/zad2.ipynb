# %%
a = 10 
b = 3.5 
c = "Python" 
d = True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# bool

# %%
a + b
# Out:
# 13.5

# %%
print(f"Wartość a to {a}, a b to {b}")
# Out:
# Wartość a to 10, a b to 3.5
