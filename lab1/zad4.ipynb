# %%
fruits = ["jabłko", "banan", "malina"] 
person = {"name": "Ala", "age": 22} 
numbers = {1, 2, 3, 3}

# %%
fruits.append("kiwi")

# %%
fruits[1]
# Out:
# 'banan'

# %%
numbers2 = [4, 8, 15, 16, 23, 42]
sum(numbers2) / len(numbers2)
# Out:
# 18.0

# %%
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# name: Ala
# age: 22
